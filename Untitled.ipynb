# %%
# Getting ready to start work on normal distributions and distribuitons in general
import numpy as np
from numpy import random
import pandas as pd


tweets = pd.read_csv('justdoit.csv')

# %%
tweets[(tweets['user_verified']== True)]
# Out:
#       tweet_contributors                                  tweet_coordinates  \
# 2                    NaN                                                NaN
# 30                   NaN                                                NaN
# 247                  NaN                                                NaN
# 348                  NaN                                                NaN
# 411                  NaN                                                NaN
# 413                  NaN                                                NaN
# 480                  NaN                                                NaN
# 509                  NaN                                                NaN
# 726                  NaN                                                NaN
# 806                  NaN                                                NaN
# 812                  NaN                                                NaN
# ...
